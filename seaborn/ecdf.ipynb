# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
sns.set()

# %%
sns.ecdfplot(df.tip)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Proportion'>

# %%
df.tip.min()
# Out:
# 1.0

# %%
print(df.tip.value_counts())
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: tip, Length: 123, dtype: int64

# %%
sns.ecdfplot(df.tip)
plt.axvline(4,c='red')

# %%
sns.ecdfplot(y=df.tip)
plt.axvline(0.5,c='red')

# %%
sns.ecdfplot(x=df.tip,hue=df.time)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Proportion'>

# %%
sns.ecdfplot(x=df.tip,hue=df.day)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Proportion'>

# %%
sns.ecdfplot(x=df.tip,hue=df.day,stat='count')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.ecdfplot(x=df.tip,stat='count',complementary=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.ecdfplot(x=df.tip,weights=df.tip)
# how much money we have made
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Proportion'>
