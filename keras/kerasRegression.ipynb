# %%
import numpy as np
import pandas as pd

# %% [markdown]
# downloading the data

# %%
concrete_data=pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# Check the dataset for any missing values

# %%
concrete_data.describe()
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# Our dataset is clean, so no need to work on it

# %% [markdown]
# split the data into predictors and targets

# %%
concrete_data_columns=concrete_data.columns
predictors=concrete_data[concrete_data_columns[concrete_data_columns!='Strength']]# all the columns except strength
target=concrete_data['Strength']

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Normalize the dataset

# %%
predictors=(predictors-predictors.mean())/predictors.std()
predictors
# Out:
#         Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0     2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1     2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2     0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3     0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4    -0.790075            0.678079 -0.846733  0.488555         -1.038638
# ...        ...                 ...       ...       ...               ...
# 1025 -0.045623            0.487998  0.564271 -0.092126          0.451190
# 1026  0.392628           -0.856472  0.959602  0.675872          0.702285
# 1027 -1.269472            0.759210  0.850222  0.521336         -0.017520
# 1028 -1.168042            1.307430 -0.846733 -0.279443          0.852942
# 1029 -0.193939            0.308349  0.376762  0.891286          0.400971
#
#       Coarse Aggregate  Fine Aggregate       Age
# ...

# %% [markdown]
# let's save the number of predictors to n_cols, since we will need them later

# %%
predictors_norm=predictors
n_col=predictors_norm.shape[1]

# %%
print(n_col)
# Out:
# 8

# %%
import keras

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
import sys
print(sys.maxsize > 2**32)
# Out:
# True

# %%
# create model
model=Sequential()
model.add(Dense(50,activation='relu',input_shape=(n_col,)))
model.add(Dense(50,activation='relu'))
model.add(Dense(1))

# compile model
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
# fit the model
model.fit(predictors,target,epochs=100,validation_split=0.3,verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 2s - loss: 1657.1703 - val_loss: 1147.9991
# Epoch 2/100
# 23/23 - 0s - loss: 1535.1099 - val_loss: 1027.5255
# Epoch 3/100
# 23/23 - 0s - loss: 1334.2369 - val_loss: 843.2808
# Epoch 4/100
# 23/23 - 0s - loss: 1030.9908 - val_loss: 597.6860
# Epoch 5/100
# 23/23 - 0s - loss: 668.8653 - val_loss: 360.6090
# Epoch 6/100
# 23/23 - 0s - loss: 394.2741 - val_loss: 219.5828
# Epoch 7/100
# 23/23 - 0s - loss: 280.3733 - val_loss: 168.0503
# Epoch 8/100
# 23/23 - 0s - loss: 245.6120 - val_loss: 150.1041
# Epoch 9/100
# 23/23 - 0s - loss: 223.9513 - val_loss: 145.8911
# Epoch 10/100
# 23/23 - 0s - loss: 211.0276 - val_loss: 137.2895
# Epoch 11/100
# 23/23 - 0s - loss: 200.7767 - val_loss: 139.1914
# Epoch 12/100
# 23/23 - 0s - loss: 193.3244 - val_loss: 135.4007
# Epoch 13/100
# 23/23 - 0s - loss: 187.0236 - val_loss: 134.2923
# Epoch 14/100
# 23/23 - 0s - loss: 181.8597 - val_loss: 133.8134
# Epoch 15/100
# 23/23 - 0s - loss: 177.4257 - val_loss: 133.1634
# ...
