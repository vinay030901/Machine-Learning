# %%
import nltk

# %%
from nltk.corpus import wordnet

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
text_str = '''
Those Who Are Resilient Stay In The Game Longer
“On the mountains of truth you can never climb in vain: either you will reach a point higher up today, or you will be training your powers so that you will be able to climb higher tomorrow.” — Friedrich Nietzsche
Challenges and setbacks are not meant to defeat you, but promote you. However, I realise after many years of defeats, it can crush your spirit and it is easier to give up than risk further setbacks and disappointments. Have you experienced this before? To be honest, I don’t have the answers. I can’t tell you what the right course of action is; only you will know. However, it’s important not to be discouraged by failure when pursuing a goal or a dream, since failure itself means different things to different people. To a person with a Fixed Mindset failure is a blow to their self-esteem, yet to a person with a Growth Mindset, it’s an opportunity to improve and find new ways to overcome their obstacles. Same failure, yet different responses. Who is right and who is wrong? Neither. Each person has a different mindset that decides their outcome. Those who are resilient stay in the game longer and draw on their inner means to succeed.
I’ve coached mummy and mom clients who gave up after many years toiling away at their respective goal or dream. It was at that point their biggest breakthrough came. Perhaps all those years of perseverance finally paid off. It was the 19th Century’s minister Henry Ward Beecher who once said: “One’s best success comes after their greatest disappointments.” No one knows what the future holds, so your only guide is whether you can endure repeated defeats and disappointments and still pursue your dream. Consider the advice from the American academic and psychologist Angela Duckworth who writes in Grit: The Power of Passion and Perseverance: “Many of us, it seems, quit what we start far too early and far too often. Even more than the effort a gritty person puts in on a single day, what matters is that they wake up the next day, and the next, ready to get on that treadmill and keep going.”
I know one thing for certain: don’t settle for less than what you’re capable of, but strive for something bigger. Some of you reading this might identify with this message because it resonates with you on a deeper level. For others, at the end of their tether the message might be nothing more than a trivial pep talk. What I wish to convey irrespective of where you are in your journey is: NEVER settle for less. If you settle for less, you will receive less than you deserve and convince yourself you are justified to receive it.
“Two people on a precipice over Yosemite Valley” by Nathan Shipps on Unsplash
Develop A Powerful Vision Of What You Want
“Your problem is to bridge the gap which exists between where you are now and the goal you intend to reach.” — Earl Nightingale
I recall a passage my father often used growing up in 1990s: “Don’t tell me your problems unless you’ve spent weeks trying to solve them yourself.” That advice has echoed in my mind for decades and became my motivator. Don’t leave it to other people or outside circumstances to motivate you because you will be let down every time. It must come from within you. Gnaw away at your problems until you solve them or find a solution. Problems are not stop signs, they are advising you that more work is required to overcome them. Most times, problems help you gain a skill or develop the resources to succeed later. So embrace your challenges and develop the grit to push past them instead of retreat in resignation. Where are you settling in your life right now? Could you be you playing for bigger stakes than you are? Are you willing to play bigger even if it means repeated failures and setbacks? You should ask yourself these questions to decide whether you’re willing to put yourself on the line or settle for less. And that’s fine if you’re content to receive less, as long as you’re not regretful later.
If you have not achieved the success you deserve and are considering giving up, will you regret it in a few years or decades from now? Only you can answer that, but you should carve out time to discover your motivation for pursuing your goals. It’s a fact, if you don’t know what you want you’ll get what life hands you and it may not be in your best interest, affirms author Larry Weidel: “Winners know that if you don’t figure out what you want, you’ll get whatever life hands you.” The key is to develop a powerful vision of what you want and hold that image in your mind. Nurture it daily and give it life by taking purposeful action towards it.
Vision + desire + dedication + patience + daily action leads to astonishing success. Are you willing to commit to this way of life or jump ship at the first sign of failure? I’m amused when I read questions written by millennials on Quora who ask how they can become rich and famous or the next Elon Musk. Success is a fickle and long game with highs and lows. Similarly, there are no assurances even if you’re an overnight sensation, to sustain it for long, particularly if you don’t have the mental and emotional means to endure it. This means you must rely on the one true constant in your favour: your personal development. The more you grow, the more you gain in terms of financial resources, status, success — simple. If you leave it to outside conditions to dictate your circumstances, you are rolling the dice on your future.
So become intentional on what you want out of life. Commit to it. Nurture your dreams. Focus on your development and if you want to give up, know what’s involved before you take the plunge. Because I assure you, someone out there right now is working harder than you, reading more books, sleeping less and sacrificing all they have to realise their dreams and it may contest with yours. Don’t leave your dreams to chance.
'''

# %%
def _create_frequency_table(text_string) -> dict:
    """
    we create a dictionary for the word frequency table.
    For this, we should only use the words that are not part of the stopWords array.
    Removing stop words and making frequency table
    Stemmer - an algorithm to bring words to its root word.
    :rtype: dict
    """
    stopWords = set(stopwords.words("english"))
    words = word_tokenize(text_string)
    ps = PorterStemmer()

    freqTable = dict()
    for word in words:
        word = ps.stem(word)
        if word in stopWords:
            continue
        if word in freqTable:
            freqTable[word] += 1
        else:
            freqTable[word] = 1

    return freqTable

# %%
def _score_sentences(sentences, freqTable) -> dict:
    """
    score a sentence by its words
    Basic algorithm: adding the frequency of every non-stop word in a sentence divided by total no of words in a sentence.
    :rtype: dict
    """

    sentenceValue = dict()

    for sentence in sentences:
        word_count_in_sentence = (len(word_tokenize(sentence)))
        word_count_in_sentence_except_stop_words = 0
        for wordValue in freqTable:
            if wordValue in sentence.lower():
                word_count_in_sentence_except_stop_words += 1
                if sentence[:10] in sentenceValue:
                    sentenceValue[sentence[:10]] += freqTable[wordValue]
                else:
                    sentenceValue[sentence[:10]] = freqTable[wordValue]

        if sentence[:10] in sentenceValue:
            sentenceValue[sentence[:10]] = sentenceValue[sentence[:10]] / word_count_in_sentence_except_stop_words

        '''
        Notice that a potential issue with our score algorithm is that long sentences will have an advantage over short sentences. 
        To solve this, we're dividing every sentence score by the number of words in the sentence.
        
        Note that here sentence[:10] is the first 10 character of any sentence, this is to save memory while saving keys of
        the dictionary.
        '''

    return sentenceValue

# %%
def _find_average_score(sentenceValue) -> int:
    """
    Find the average score from the sentence value dictionary
    :rtype: int
    """
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    """[summary]

    Returns:
        [type]: [description]
    """    # Average value of a sentence from original text
    average = (sumValues / len(sentenceValue))

    return average

# %%
def _generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = ''

    for sentence in sentences:
        if sentence[:10] in sentenceValue and sentenceValue[sentence[:10]] >= (threshold):
            summary += " " + sentence
            sentence_count += 1

    return summary

# %%
def run_summarization(text):
    # 1 Create the word frequency table
    freq_table = _create_frequency_table(text)

    '''
    We already have a sentence tokenizer, so we just need 
    to run the sent_tokenize() method to create the array of sentences.
    '''

    # 2 Tokenize the sentences
    sentences = sent_tokenize(text)

    # 3 Important Algorithm: score the sentences
    sentence_scores = _score_sentences(sentences, freq_table)

    # 4 Find the threshold
    threshold = _find_average_score(sentence_scores)

    # 5 Important Algorithm: Generate the summary
    summary = _generate_summary(sentences, sentence_scores, 1.3 * threshold)

    return summary

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
result = run_summarization(text_str)
print(result)
# Out:
#  To be honest, I don’t have the answers. Same failure, yet different responses. Neither. Don’t leave it to other people or outside circumstances to motivate you because you will be let down every time. And that’s fine if you’re content to receive less, as long as you’re not regretful later. Commit to it. Nurture your dreams. Don’t leave your dreams to chance.

# %%
from nltk.corpus import wordnet as wn

# %%
result=result.strip()
lis=result.split(" ")
print(lis)
for i in lis:
    print(i)
    if wn.synsets(i):
        syn=wn.synsets(i)[0]
        print(syn.hypernyms(),"\n")
# Out:
# ['To', 'be', 'honest,', 'I', 'don’t', 'have', 'the', 'answers.', 'Same', 'failure,', 'yet', 'different', 'responses.', 'Neither.', 'Don’t', 'leave', 'it', 'to', 'other', 'people', 'or', 'outside', 'circumstances', 'to', 'motivate', 'you', 'because', 'you', 'will', 'be', 'let', 'down', 'every', 'time.', 'And', 'that’s', 'fine', 'if', 'you’re', 'content', 'to', 'receive', 'less,', 'as', 'long', 'as', 'you’re', 'not', 'regretful', 'later.', 'Commit', 'to', 'it.', 'Nurture', 'your', 'dreams.', 'Don’t', 'leave', 'your', 'dreams', 'to', 'chance.']
# To
# be
# [Synset('metallic_element.n.01')]
#
# honest,
# I
# [Synset('chemical_element.n.01'), Synset('halogen.n.01')]
#
# don’t
# have
# [Synset('person.n.01')]
#
# the
# answers.
# Same
# [Synset('european.n.01')]
#
# failure,
# yet
# []
#
# different
# []
#
# responses.
# Neither.
# Don’t
# leave
# [Synset('time_off.n.01')]
#
# it
# [Synset('engineering.n.02')]
#
# to
# other
# []
#
# people
# [Synset('group.n.01')]
#
# or
# []
#
# outside
# [Synset('region.n.01')]
#
# circumstances
# [Synset('condition.n.03')]
#
# to
# motivate
# [Synset('cause.v.01')]
#
# you
# because
# you
# will
# [Synset('faculty.n.01')]
#
# be
# [Synset('metallic_element.n.01')]
#
# let
# []
#
# down
# [Synset('feather.n.01')]
#
# every
# []
#
# time.
# And
# that’s
# fine
# [Synset('penalty.n.02')]
#
# if
# you’re
# content
# [Synset('collection.n.01')]
#
# to
# receive
# [Synset('get.v.01')]
#
# less,
# as
# [Synset('chemical_element.n.01')]
#
# long
# [Synset('desire.v.01')]
#
# as
# [Synset('chemical_element.n.01')]
#
# you’re
# not
# []
#
# regretful
# []
#
# later.
# Commit
# [Synset('act.v.01')]
#
# to
# it.
# Nurture
# [Synset('upbringing.n.01')]
#
# your
# dreams.
# Don’t
# leave
# [Synset('time_off.n.01')]
#
# your
# dreams
# [Synset('imagination.n.02')]
#
# to
# chance.

# %%
print(syn)
syn=wn.synsets('brother')
print(syn)
print(syn.definition())
# Out:
# [Synset('brother.n.01'), Synset('brother.n.02'), Synset('buddy.n.01'), Synset('brother.n.04'), Synset('brother.n.05')]
# [Synset('brother.n.01'), Synset('brother.n.02'), Synset('buddy.n.01'), Synset('brother.n.04'), Synset('brother.n.05')]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2344/3322849815.py in <module>
#       2 syn=wn.synsets('brother')
#       3 print(syn)
# ----> 4 print(syn.definition())
#
# AttributeError: 'list' object has no attribute 'definition'

# %%
print(lis)
# Out:
# ['To', 'be', 'honest,', 'I', 'don’t', 'have', 'the', 'answers.', 'Same', 'failure,', 'yet', 'different', 'responses.', 'Neither.', 'Don’t', 'leave', 'it', 'to', 'other', 'people', 'or', 'outside', 'circumstances', 'to', 'motivate', 'you', 'because', 'you', 'will', 'be', 'let', 'down', 'every', 'time.', 'And', 'that’s', 'fine', 'if', 'you’re', 'content', 'to', 'receive', 'less,', 'as', 'long', 'as', 'you’re', 'not', 'regretful', 'later.', 'Commit', 'to', 'it.', 'Nurture', 'your', 'dreams.', 'Don’t', 'leave', 'your', 'dreams', 'to', 'chance.']

# %%
def check_pos(n):
    if n=='n':
        return 'noun'
    if n=='v':
        return 'verb'
    if n=='a':
        return 'adjective'
    if n=='r':
        return 'adverb'

# %%
def getInfo(word1):
        List1 = []
        for data1 in word1:
              wordnetSynset1 = wn.synsets(data1)      
              if len(wordnetSynset1)>1:
                print("\nreal word: ",data1)
                print("lemma first word :",wordnetSynset1[0].name())
                print("its meaning: ",wordnetSynset1[0].definition())
                print("examples: ",wordnetSynset1[0].examples())
                print("Part of speech: ",check_pos(wordnetSynset1[0].pos()))
                  
                print("\nlemma second word :",wordnetSynset1[1].name())
                print("its meaning: ",wordnetSynset1[1].definition())
                print("examples: ",wordnetSynset1[1].examples())
                print("Part of speech: ",check_pos(wordnetSynset1[1].pos()))
                
                synonyms=[]
                antonyms=[]
                for syn in wordnetSynset1:
                        for l in syn.lemmas():
                                synonyms.append(l.name())
                                if l.antonyms():
                                        antonyms.append(l.antonyms()[0].name())
                print("synonyms: ",synonyms)
                print("\nantonyms: ",antonyms)     
   
print(getInfo(lis))
# Out:
# real word:  be
# lemma first word : beryllium.n.01
# its meaning:  a light strong brittle grey toxic bivalent metallic element
# examples:  []
# Part of speech:  noun
#
# lemma second word : be.v.01
# its meaning:  have the quality of being; (copula, used with an adjective or a predicate noun)
# examples:  ['John is rich', 'This is not a good answer']
# Part of speech:  verb
# synonyms:  ['beryllium', 'Be', 'glucinium', 'atomic_number_4', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make_up', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
#
# antonyms:  ['differ']
#
# real word:  I
# lemma first word : iodine.n.01
# its meaning:  a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
# examples:  []
# Part of speech:  noun
#
# lemma second word : one.n.01
# its meaning:  the smallest whole number or a numeral representing this number
# examples:  ['he has the one but will need a two and three to go with it', 'they had lunch at one']
# Part of speech:  noun
# synonyms:  ['iodine', 'iodin', 'I', 'atomic_number_53', 'one', '1', 'I', 'ace', 'single', 'unity', 'I', 'i', 'one', '1', 'i', 'ane']
#
# antonyms:  []
#
# real word:  have
# lemma first word : rich_person.n.01
# its meaning:  a person who possesses great material wealth
# examples:  []
# Part of speech:  noun
#
# lemma second word : have.v.01
# its meaning:  have or possess, either in a concrete or an abstract sense
# examples:  ['She has $1,000 in the bank', 'He has got two beautiful daughters', "She holds a Master's degree from Harvard"]
# Part of speech:  verb
# synonyms:  ['rich_person', 'wealthy_person', 'have', 'have', 'have_got', 'hold', 'have', 'feature', 'experience', 'receive', 'have', 'get', 'own', 'have', 'possess', 'get', 'let', 'have', 'consume', 'ingest', 'take_in', 'take', 'have', 'have', 'hold', 'throw', 'have', 'make', 'give', 'have', 'have', 'have', 'experience', 'have', 'induce', 'stimulate', 'cause', 'have', 'get', 'make', 'accept', 'take', 'have', 'receive', 'have', 'suffer', 'sustain', 'have', 'get', 'have', 'get', 'make', 'give_birth', 'deliver', 'bear', 'birth', 'have', 'take', 'have']
#
# antonyms:  ['lack', 'abstain', 'refuse']
#
# real word:  Same
# lemma first word : lapp.n.01
# its meaning:  a member of an indigenous nomadic people living in northern Scandinavia and herding reindeer
# examples:  []
# Part of speech:  noun
#
# lemma second word : lapp.n.02
# its meaning:  the language of nomadic Lapps in northern Scandinavia and the Kola Peninsula
# examples:  []
# Part of speech:  noun
# synonyms:  ['Lapp', 'Lapplander', 'Sami', 'Saami', 'Same', 'Saame', 'Lapp', 'Sami', 'Saami', 'Same', 'Saame', 'same', 'same', 'like', 'same', 'same']
#
# antonyms:  ['other', 'different', 'unlike']
#
# real word:  yet
# lemma first word : yet.r.01
# its meaning:  up to the present time
# examples:  ['I have yet to see the results', 'details are yet to be worked out']
# Part of speech:  adverb
#
# lemma second word : so_far.r.01
# its meaning:  used in negative statement to describe a situation that has existed up to this point or up to the present time
# examples:  ["So far he hasn't called", "the sun isn't up yet"]
# Part of speech:  adverb
# synonyms:  ['yet', 'so_far', 'thus_far', 'up_to_now', 'hitherto', 'heretofore', 'as_yet', 'yet', 'til_now', 'until_now', 'even', 'yet', 'still', 'yet', 'in_time', 'so_far', 'yet', 'however', 'nevertheless', 'withal', 'still', 'yet', 'all_the_same', 'even_so', 'nonetheless', 'notwithstanding']
#
# antonyms:  []
#
# real word:  different
# lemma first word : different.a.01
# its meaning:  unlike in nature or quality or form or degree
# examples:  ['took different approaches to the problem', 'came to a different conclusion', 'different parts of the country', 'on different sides of the issue', 'this meeting was different from the earlier one']
# Part of speech:  adjective
#
# lemma second word : different.s.02
# its meaning:  distinctly separate from the first
# examples:  ["that's another (or different) issue altogether"]
# Part of speech:  None
# synonyms:  ['different', 'different', 'different', 'unlike', 'dissimilar', 'different', 'different']
#
# antonyms:  ['same', 'like']
#
# real word:  leave
# lemma first word : leave.n.01
# its meaning:  the period of time during which you are absent from work or duty
# examples:  ["a ten day's leave to visit his mother"]
# Part of speech:  noun
#
# lemma second word : leave.n.02
# its meaning:  permission to do something
# examples:  ['she was granted leave to speak']
# Part of speech:  noun
# synonyms:  ['leave', 'leave_of_absence', 'leave', 'farewell', 'leave', 'leave-taking', 'parting', 'leave', 'go_forth', 'go_away', 'leave', 'leave', 'leave', 'leave_alone', 'leave_behind', 'exit', 'go_out', 'get_out', 'leave', 'leave', 'allow_for', 'allow', 'provide', 'leave', 'result', 'lead', 'leave', 'depart', 'pull_up_stakes', 'entrust', 'leave', 'bequeath', 'will', 'leave', 'leave', 'leave', 'leave_behind', 'impart', 'leave', 'give', 'pass_on', 'forget', 'leave']
#
# antonyms:  ['arrive', 'enter', 'disinherit']
#
# real word:  other
# lemma first word : other.a.01
# its meaning:  not the same one or ones already mentioned or implied; - the White Queen
# examples:  ["today isn't any other day", 'the construction of highways and other public works', 'he asked for other employment', 'any other person would tell the truth', 'his other books are still in storage', 'then we looked at the other house', 'hearing was good in his other ear', 'the other sex', 'she lived on the other side of the street from me', 'went in the other direction']
# Part of speech:  adjective
#
# lemma second word : other.s.02
# its meaning:  recently past
# examples:  ['the other evening']
# Part of speech:  None
# synonyms:  ['other', 'other', 'early', 'former', 'other', 'other']
#
# antonyms:  ['same']
#
# real word:  people
# lemma first word : people.n.01
# its meaning:  (plural) any group of human beings (men or women or children) collectively
# examples:  ['old people', 'there were at least 200 people in the audience']
# Part of speech:  noun
#
# lemma second word : citizenry.n.01
# its meaning:  the body of citizens of a state or country
# examples:  ['the Spanish people']
# Part of speech:  noun
# synonyms:  ['people', 'citizenry', 'people', 'people', 'multitude', 'masses', 'mass', 'hoi_polloi', 'people', 'the_great_unwashed', 'people', 'people']
#
# antonyms:  []
#
# real word:  or
# lemma first word : oregon.n.01
# its meaning:  a state in northwestern United States on the Pacific
# examples:  []
# Part of speech:  noun
#
# lemma second word : operating_room.n.01
# its meaning:  a room in a hospital equipped for the performance of surgical operations
# examples:  ['great care is taken to keep the operating rooms aseptic']
# Part of speech:  noun
# synonyms:  ['Oregon', 'Beaver_State', 'OR', 'operating_room', 'OR', 'operating_theater', 'operating_theatre', 'surgery']
#
# antonyms:  []
#
# real word:  outside
# lemma first word : outside.n.01
# its meaning:  the region that is outside of something
# examples:  []
# Part of speech:  noun
#
# lemma second word : outside.n.02
# its meaning:  the outer side or surface of something
# examples:  []
# Part of speech:  noun
# synonyms:  ['outside', 'exterior', 'outside', 'exterior', 'outside', 'external', 'extraneous', 'outside', 'outside', 'outdoor', 'out-of-door', 'outside', 'outside', 'outside', 'external', 'international', 'outside', 'outside', 'remote', 'outside', 'away', 'outside', 'outside', 'outdoors', 'out_of_doors', 'alfresco', 'outside']
#
# antonyms:  ['inside', 'inside', 'inside', 'indoor', 'inside', 'indoors', 'inside']
#
# real word:  circumstances
# lemma first word : fortune.n.04
# its meaning:  your overall circumstances or condition in life (including everything that happens to you)
# examples:  ['whatever my fortune may be', 'deserved a better fate', 'has a happy lot', 'the luck of the Irish', 'a victim of circumstances', 'success that was her portion']
# Part of speech:  noun
#
# lemma second word : circumstances.n.02
# its meaning:  a person's financial situation (good or bad)
# examples:  ['he found himself in straitened circumstances']
# Part of speech:  noun
# synonyms:  ['fortune', 'destiny', 'fate', 'luck', 'lot', 'circumstances', 'portion', 'circumstances', 'circumstance', 'context', 'circumstance', 'setting', 'circumstance', 'condition', 'consideration', 'circumstance']
#
# antonyms:  []
#
# real word:  will
# lemma first word : volition.n.01
# its meaning:  the capability of conscious choice and decision and intention; - George Meredith
# examples:  ['the exercise of their volition we construe as revolt']
# Part of speech:  noun
#
# lemma second word : will.n.02
# its meaning:  a fixed and persistent intent or purpose
# examples:  ["where there's a will there's a way"]
# Part of speech:  noun
# synonyms:  ['volition', 'will', 'will', 'will', 'testament', 'will', 'will', 'bequeath', 'will', 'leave']
#
# antonyms:  ['disinherit']
#
# real word:  be
# lemma first word : beryllium.n.01
# its meaning:  a light strong brittle grey toxic bivalent metallic element
# examples:  []
# Part of speech:  noun
#
# lemma second word : be.v.01
# its meaning:  have the quality of being; (copula, used with an adjective or a predicate noun)
# examples:  ['John is rich', 'This is not a good answer']
# Part of speech:  verb
# synonyms:  ['beryllium', 'Be', 'glucinium', 'atomic_number_4', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make_up', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
#
# antonyms:  ['differ']
#
# real word:  let
# lemma first word : lashkar-e-taiba.n.01
# its meaning:  a brutal terrorist group active in Kashmir; fights against India with the goal of restoring Islamic rule of India
# examples:  ['Lashkar-e-Toiba has committed mass murders of civilian Hindus']
# Part of speech:  noun
#
# lemma second word : let.n.02
# its meaning:  a serve that strikes the net before falling into the receiver's court; the ball must be served again
# examples:  []
# Part of speech:  noun
# synonyms:  ['Lashkar-e-Taiba', 'Lashkar-e-Toiba', 'Lashkar-e-Tayyiba', 'LET', 'Army_of_the_Pure', 'Army_of_the_Righteous', 'let', 'net_ball', 'let', 'allow', 'permit', 'let', 'permit', 'allow', 'let', 'countenance', 'get', 'let', 'have', 'let', 'lease', 'let', 'rent']
#
# antonyms:  ['prevent', 'forbid', 'disallow']
#
# real word:  down
# lemma first word : down.n.01
# its meaning:  soft fine feathers
# examples:  []
# Part of speech:  noun
#
# lemma second word : down.n.02
# its meaning:  (American football) a complete play to advance the football
# examples:  ['you have four downs to gain ten yards']
# Part of speech:  noun
# synonyms:  ['down', 'down_feather', 'down', 'Down', 'John_L._H._Down', 'down', 'down', 'pile', 'toss_off', 'pop', 'bolt_down', 'belt_down', 'pour_down', 'down', 'drink_down', 'kill', 'devour', 'down', 'consume', 'go_through', 'down', 'down', 'shoot_down', 'land', 'down', 'knock_down', 'cut_down', 'push_down', 'pull_down', 'polish', 'refine', 'fine-tune', 'down', 'down', 'down', 'downward', 'down', 'down', 'down', 'down_pat', 'mastered', 'depressed', 'down', 'down', 'down', 'gloomy', 'grim', 'blue', 'depressed', 'dispirited', 'down', 'downcast', 'downhearted', 'down_in_the_mouth', 'low', 'low-spirited', 'down', 'downwards', 'downward', 'downwardly', 'down', 'down', 'down', 'down', 'down']
#
# antonyms:  ['up', 'up', 'upwards', 'upward', 'upwardly', 'up', 'up']
#
# real word:  every
# lemma first word : every.s.01
# its meaning:  (used of count nouns) each and all of the members of a group considered singly and without exception
# examples:  ['every person is mortal', 'every party is welcome', 'had every hope of success', 'every chance of winning']
# Part of speech:  None
#
# lemma second word : every.s.02
# its meaning:  each and all of a series of entities or intervals as specified
# examples:  ['every third seat', 'every two hours']
# Part of speech:  None
# synonyms:  ['every', 'every']
#
# antonyms:  []
#
# real word:  fine
# lemma first word : fine.n.01
# its meaning:  money extracted as a penalty
# examples:  []
# Part of speech:  noun
#
# lemma second word : ticket.v.01
# its meaning:  issue a ticket or a fine to as a penalty
# examples:  ['I was fined for parking on the wrong side of the street', 'Move your car or else you will be ticketed!']
# Part of speech:  verb
# synonyms:  ['fine', 'mulct', 'amercement', 'ticket', 'fine', 'all_right', 'fine', 'o.k.', 'ok', 'okay', 'hunky-dory', 'fine', 'fine', 'fine', 'fine', 'fine', 'very_well', 'fine', 'alright', 'all_right', 'OK', 'finely', 'fine', 'delicately', 'exquisitely']
#
# antonyms:  ['coarse']
#
# real word:  content
# lemma first word : content.n.01
# its meaning:  everything that is included in a collection and that is held or included in something
# examples:  ['he emptied the contents of his pockets', 'the two groups were similar in content']
# Part of speech:  noun
#
# lemma second word : message.n.02
# its meaning:  what a communication that is about something is about
# examples:  []
# Part of speech:  noun
# synonyms:  ['content', 'message', 'content', 'subject_matter', 'substance', 'content', 'capacity', 'content', 'content', 'cognitive_content', 'mental_object', 'contentedness', 'content', 'subject', 'content', 'depicted_object', 'content', 'content', 'contented', 'content']
#
# antonyms:  ['discontent', 'discontented']
#
# real word:  receive
# lemma first word : receive.v.01
# its meaning:  get something; come into possession of
# examples:  ['receive payment', 'receive a gift', 'receive letters from the front']
# Part of speech:  verb
#
# lemma second word : receive.v.02
# its meaning:  receive a specified treatment (abstract)
# examples:  ['These aspects of civilization do not find expression or receive an interpretation', 'His movie received a good review', 'I got nothing but trouble for my good intentions']
# Part of speech:  verb
# synonyms:  ['receive', 'have', 'receive', 'get', 'find', 'obtain', 'incur', 'pick_up', 'receive', 'experience', 'receive', 'have', 'get', 'receive', 'take_in', 'invite', 'receive', 'welcome', 'receive', 'receive', 'meet', 'encounter', 'receive', 'receive', 'get', 'receive', 'receive', 'receive']
#
# antonyms:  ['say_farewell']
#
# real word:  as
# lemma first word : arsenic.n.02
# its meaning:  a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar
# examples:  []
# Part of speech:  noun
#
# lemma second word : american_samoa.n.01
# its meaning:  a United States territory on the eastern part of the island of Samoa
# examples:  []
# Part of speech:  noun
# synonyms:  ['arsenic', 'As', 'atomic_number_33', 'American_Samoa', 'Eastern_Samoa', 'AS', 'angstrom', 'angstrom_unit', 'A', 'vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A', 'deoxyadenosine_monophosphate', 'A', 'adenine', 'A', 'ampere', 'amp', 'A', 'A', 'a', 'A', 'type_A', 'group_A', 'equally', 'as', 'every_bit']
#
# antonyms:  []
#
# real word:  long
# lemma first word : hanker.v.01
# its meaning:  desire strongly or persistently
# examples:  []
# Part of speech:  verb
#
# lemma second word : long.a.01
# its meaning:  primarily temporal sense; being or indicating a relatively great or greater than average duration or passage of time or a duration as specified
# examples:  ['a long life', 'a long boring speech', 'a long time', 'a long friendship', 'a long game', 'long ago', 'an hour long']
# Part of speech:  adjective
# synonyms:  ['hanker', 'long', 'yearn', 'long', 'long', 'long', 'retentive', 'recollective', 'long', 'tenacious', 'long', 'long', 'long', 'farseeing', 'farsighted', 'foresighted', 'foresightful', 'prospicient', 'long', 'longsighted', 'long', 'long', 'long']
#
# antonyms:  ['short', 'short', 'unretentive', 'short', 'short']
#
# real word:  as
# lemma first word : arsenic.n.02
# its meaning:  a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar
# examples:  []
# Part of speech:  noun
#
# lemma second word : american_samoa.n.01
# its meaning:  a United States territory on the eastern part of the island of Samoa
# examples:  []
# Part of speech:  noun
# synonyms:  ['arsenic', 'As', 'atomic_number_33', 'American_Samoa', 'Eastern_Samoa', 'AS', 'angstrom', 'angstrom_unit', 'A', 'vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A', 'deoxyadenosine_monophosphate', 'A', 'adenine', 'A', 'ampere', 'amp', 'A', 'A', 'a', 'A', 'type_A', 'group_A', 'equally', 'as', 'every_bit']
#
# antonyms:  []
#
# real word:  Commit
# lemma first word : perpetrate.v.01
# its meaning:  perform an act, usually with a negative connotation
# examples:  ['perpetrate a crime', 'pull a bank robbery']
# Part of speech:  verb
#
# lemma second word : give.v.18
# its meaning:  give entirely to a specific person, activity, or cause
# examples:  ['She committed herself to the work of God', "give one's talents to a good cause", 'consecrate your life to the church']
# Part of speech:  verb
# synonyms:  ['perpetrate', 'commit', 'pull', 'give', 'dedicate', 'consecrate', 'commit', 'devote', 'commit', 'institutionalize', 'institutionalise', 'send', 'charge', 'entrust', 'intrust', 'trust', 'confide', 'commit', 'invest', 'put', 'commit', 'place', 'commit', 'practice']
#
# antonyms:  ['divest']
#
# real word:  Nurture
# lemma first word : raising.n.02
# its meaning:  the properties acquired as a consequence of the way you were treated as a child
# examples:  []
# Part of speech:  noun
#
# lemma second word : breeding.n.03
# its meaning:  helping someone grow up to be an accepted member of the community
# examples:  ['they debated whether nature or nurture was more important']
# Part of speech:  noun
# synonyms:  ['raising', 'rearing', 'nurture', 'breeding', 'bringing_up', 'fostering', 'fosterage', 'nurture', 'raising', 'rearing', 'upbringing', 'foster', 'nurture', 'rear', 'raise', 'bring_up', 'nurture', 'parent', 'nourish', 'nurture', 'sustain']
#
# antonyms:  []
#
# real word:  leave
# lemma first word : leave.n.01
# its meaning:  the period of time during which you are absent from work or duty
# examples:  ["a ten day's leave to visit his mother"]
# Part of speech:  noun
#
# lemma second word : leave.n.02
# its meaning:  permission to do something
# examples:  ['she was granted leave to speak']
# Part of speech:  noun
# synonyms:  ['leave', 'leave_of_absence', 'leave', 'farewell', 'leave', 'leave-taking', 'parting', 'leave', 'go_forth', 'go_away', 'leave', 'leave', 'leave', 'leave_alone', 'leave_behind', 'exit', 'go_out', 'get_out', 'leave', 'leave', 'allow_for', 'allow', 'provide', 'leave', 'result', 'lead', 'leave', 'depart', 'pull_up_stakes', 'entrust', 'leave', 'bequeath', 'will', 'leave', 'leave', 'leave', 'leave_behind', 'impart', 'leave', 'give', 'pass_on', 'forget', 'leave']
#
# antonyms:  ['arrive', 'enter', 'disinherit']
#
# real word:  dreams
# lemma first word : dream.n.01
# its meaning:  a series of mental images and emotions occurring during sleep
# examples:  ['I had a dream about you last night']
# Part of speech:  noun
#
# lemma second word : dream.n.02
# its meaning:  imaginative thoughts indulged in while awake
# examples:  ['he lives in a dream that has nothing to do with reality']
# Part of speech:  noun
# synonyms:  ['dream', 'dreaming', 'dream', 'dreaming', 'ambition', 'aspiration', 'dream', 'pipe_dream', 'dream', 'dream', 'dream', 'dream', 'daydream', 'woolgather', 'stargaze', 'dream']
#
# antonyms:  []
# None

# %%
from nltk.corpus import wordnet as wn


def getSynonyms(word1):
        synonymList1 = {}
        for data1 in word1:
              wordnetSynset1 = wn.synsets(data1)
              tempList1=[]
              for synset1 in wordnetSynset1:
                 for synWords1 in synset1.lemma_names():
                     tempList1.append(synWords1)
              synonymList1[data1]=tempList1
        return synonymList1

# %%
word1 =  ['feds', 'move', 'to', 'require', 'cartocar', 'safety', 'communication']
print(getSynonyms(word1))
# Out:
# {'feds': ['Federal', 'Fed', 'federal_official', 'Federal_Reserve_System', 'Federal_Reserve', 'Fed', 'FRS'], 'move': ['move', 'move', 'relocation', 'motion', 'movement', 'move', 'motility', 'motion', 'movement', 'move', 'move', 'travel', 'go', 'move', 'locomote', 'move', 'displace', 'move', 'move', 'go', 'proceed', 'move', 'be_active', 'move', 'move', 'act', 'move', 'affect', 'impress', 'move', 'strike', 'motivate', 'actuate', 'propel', 'move', 'prompt', 'incite', 'move', 'move', 'move', 'go', 'run', 'move', 'move', 'go', 'move', 'make_a_motion'], 'to': [], 'require': ['necessitate', 'ask', 'postulate', 'need', 'require', 'take', 'involve', 'call_for', 'demand', 'ask', 'require', 'expect', 'command', 'require', 'want', 'need', 'require'], 'cartocar': [], 'safety': ['safety', 'safety', 'refuge', 'guard', 'safety', 'safety_device', 'base_hit', 'safety', 'condom', 'rubber', 'safety', 'safe', 'prophylactic', 'safety'], 'communication': ['communication', 'communicating', 'communication', 'communication']}

# %%
w1=wn.synset('ship.n.01')
w2=wn.synset('boat.n.01')
print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091
